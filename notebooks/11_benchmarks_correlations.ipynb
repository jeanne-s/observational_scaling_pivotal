# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %cd ..
from utils.data import get_full_post_training_df
# Out:
# /scratch2/jsalle

# %%
evals, subtasks = get_full_post_training_df()
tasks = ['MMLU', 'ARC-C', 'HellaSwag', 'Winograd', 'TruthfulQA', 'XWinograd', 'HumanEval', 'GSM8K'] # + subtasks

subevals = evals[tasks]
corr = subevals.corr()
sns.heatmap(corr, annot=True, fmt=".1f")
# Out:
# <Axes: >

# %%
tasks = ['MMLU', 'ARC-C', 'HellaSwag', 'Winograd', 'TruthfulQA', 'XWinograd', 'HumanEval', 'GSM8K'] + subtasks

plt.figure(figsize=(13, 13))
subevals = evals[tasks]
corr = subevals.corr()
sns.heatmap(corr, annot=True, fmt=".1f", annot_kws={"fontsize":8})
# Out:
# <Axes: >
